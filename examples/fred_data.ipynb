# %%
import sys
sys.path.append("..")

from pyeconomics.fred_data import fetch_fed_rate

# %%
fed_rate = fetch_fed_rate()

# %%
fed_rate.plot();

# %%
fed_rate.iloc[-1]
# Out:
# 5.5

# %%
fed_rate
# Out:
# 1982-09-27    10.25
# 1982-09-28    10.25
# 1982-09-29    10.25
# 1982-09-30    10.25
# 1982-10-01    10.00
#               ...
# 2024-04-30     5.50
# 2024-05-01     5.50
# 2024-05-02     5.50
# 2024-05-03     5.50
# 2024-05-04     5.50
# Length: 15196, dtype: float64
